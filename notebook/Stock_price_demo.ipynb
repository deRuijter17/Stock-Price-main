# %% [markdown]
# # Đọc dữ liệu và phân tích

# %%
from pyspark.context import SparkContext
from IPython.display import Image
from pyspark.sql import SparkSession
from pyspark.sql.functions import year, expr
import pandas as pd
import matplotlib.pyplot as plt

# %%
spark = SparkSession.builder \
    .appName("Stocks-price-Analysis") \
    .master("spark://spark-master:7077") \
    .config("spark.hadoop.fs.defaultFS", "hdfs://namenode:9000") \
    .getOrCreate()

print(spark.version)
# Out:
# 25/10/26 03:25:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 3.1.1

# %%
df_ACB = spark.read.csv("hdfs://namenode:9000/datack/ACB.csv", header=True, inferSchema=True)
df_BCM = spark.read.csv("hdfs://namenode:9000/datack/BCM.csv", header=True, inferSchema=True)
df_BID = spark.read.csv("hdfs://namenode:9000/datack/BID.csv", header=True, inferSchema=True)
df_CTG = spark.read.csv("hdfs://namenode:9000/datack/CTG.csv", header=True, inferSchema=True)
df_DGC = spark.read.csv("hdfs://namenode:9000/datack/DGC.csv", header=True, inferSchema=True)
df_FPT = spark.read.csv("hdfs://namenode:9000/datack/FPT.csv", header=True, inferSchema=True)

# %%
df_ACBmean = df_ACB.withColumn("mean", expr('(high+low)/2'))
df_BCMmean = df_BCM.withColumn("mean", expr('(high+low)/2'))
df_BIDmean = df_BID.withColumn("mean", expr('(high+low)/2'))
df_CTGmean = df_CTG.withColumn("mean", expr('(high+low)/2'))
df_DGCmean = df_DGC.withColumn("mean", expr('(high+low)/2'))
df_FPTmean = df_FPT.withColumn("mean", expr('(high+low)/2'))

# %%
df_ACBmean = df_ACBmean.toPandas()
df_BCMmean = df_BCMmean.toPandas()         
df_BIDmean = df_BIDmean.toPandas()
df_CTGmean = df_CTGmean.toPandas()
df_DGCmean = df_DGCmean.toPandas()
df_FPTmean = df_FPTmean.toPandas()

# %%
ax = df_ACBmean.plot(x='time', y= 'mean', label='ACB', figsize=(16,6))
ax = df_BCMmean.plot(ax=ax, x= 'time', y= 'mean',label='BCM')
ax = df_BIDmean.plot(ax=ax, x= 'time', y= 'mean',label='BID')
ax = df_CTGmean.plot(ax=ax, x= 'time', y= 'mean',label='CTG')
ax = df_DGCmean.plot(ax=ax, x= 'time', y= 'mean',label='DGC')
df_FPTmean.plot(ax=ax, x= 'time', y= 'mean',label='FPT')
# Out:
# <Axes: xlabel='time'>

# %%
df_ACBmean['change']= (df_ACBmean['close']/df_ACBmean['close'].shift(1)) - 1 
df_BCMmean['change']= (df_BCMmean['close']/df_BCMmean['close'].shift(1)) - 1 
df_BIDmean['change']= (df_BIDmean['close']/df_BIDmean['close'].shift(1)) - 1

# %%
df_ACBmean['change'].hist(bins=100, label='ACB', alpha=0.5)
df_BCMmean['change'].hist(bins=100, label='BCM', alpha=0.5)
df_BIDmean['change'].hist(bins=100, label='BID', alpha=0.5)
plt.legend()

# %%
df_ACBmean['change'].plot(kind= 'kde', label = 'ACB')
df_BCMmean['change'].plot(kind= 'kde', label = 'BCM')
df_BIDmean['change'].plot(kind= 'kde', label = 'BID')
plt.legend()

# %%
# !pip install mplfinance
import mplfinance as mpf

# Lấy dữ liệu của cổ phiếu FPT để vẽ biểu đồ nến
df_fpt_pandas = df_FPT.toPandas()
df_fpt_pandas['time'] = pd.to_datetime(df_fpt_pandas['time'])
df_fpt_pandas.set_index('time', inplace=True)

# Vẽ biểu đồ nến cho 2 tháng cuối cùng
mpf.plot(df_fpt_pandas.tail(60), type='candle', style='yahoo',
         title='Biểu đồ nến giá cổ phiếu FPT (60 ngày cuối)',
         ylabel='Giá (VND)',
         volume=True,
         ylabel_lower='Khối lượng giao dịch')
# Out:
# Requirement already satisfied: mplfinance in /opt/conda/lib/python3.11/site-packages (0.12.10b0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (from mplfinance) (3.10.7)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from mplfinance) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib->mplfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->mplfinance) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->mplfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->mplfinance) (1.16.0)

# %%
# Tính toán đường trung bình động cho cổ phiếu FPT
df_fpt_pandas['MA10'] = df_fpt_pandas['close'].rolling(window=10).mean()
df_fpt_pandas['MA50'] = df_fpt_pandas['close'].rolling(window=50).mean()

# Vẽ biểu đồ giá đóng cửa và các đường MA
plt.figure(figsize=(16, 6))
plt.plot(df_fpt_pandas['close'], label='Giá đóng cửa FPT')
plt.plot(df_fpt_pandas['MA10'], label='MA 10 ngày')
plt.plot(df_fpt_pandas['MA50'], label='MA 50 ngày')
plt.title('Giá đóng cửa và đường trung bình động của cổ phiếu FPT')
plt.xlabel('Thời gian')
plt.ylabel('Giá (VND)')
plt.legend()
plt.show()

# %%
#Tính toán lợi nhuận hàng ngày cho các cổ phiếu
df_ACBmean['daily_return'] = df_ACBmean['close'].pct_change()
df_BCMmean['daily_return'] = df_BCMmean['close'].pct_change()
df_BIDmean['daily_return'] = df_BIDmean['close'].pct_change()
#Vẽ biểu đồ phân phối lợi nhuận
plt.figure(figsize=(12, 6))
df_ACBmean['daily_return'].hist(bins=100, label='ACB', alpha=0.6)
df_BCMmean['daily_return'].hist(bins=100, label='BCM', alpha=0.6)
df_BIDmean['daily_return'].hist(bins=100, label='BID', alpha=0.6)
plt.title('Phân phối lợi nhuận hàng ngày')
plt.xlabel('Lợi nhuận')
plt.ylabel('Tần suất')
plt.legend()
plt.show()

# %%
spark.stop()
